# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import matplotlib.pyplot as plt

# %%
query = "arvidkahl"
limit = 5000
tweets = []

# %%
tweets = []
for tweet in sntwitter.TwitterUserScraper(query).get_items():
		if len(tweets) == limit:
			break 
		else:
			tweets.append([tweet.date, tweet.id, tweet.content, tweet.url, tweet.likeCount, tweet.inReplyToTweetId])
			# tweets.append([vars(tweet)])
tweets
# Out:
# [[datetime.datetime(2022, 10, 10, 0, 48, 5, tzinfo=datetime.timezone.utc),
#   1579272521752666112,
#   '@TheAbbyOfComedy I will go about this calmly :)',
#   'https://twitter.com/arvidkahl/status/1579272521752666112',
#   2,
#   1579268166592524288],
#  [datetime.datetime(2022, 10, 9, 23, 2, 58, tzinfo=datetime.timezone.utc),
#   1579246068944220160,
#   '@diogo_gonca Haha, I’ll do my best!',
#   'https://twitter.com/arvidkahl/status/1579246068944220160',
#   1,
#   1579238317505138688],
#  [datetime.datetime(2022, 10, 9, 22, 54, 10, tzinfo=datetime.timezone.utc),
#   1579243854527877120,
#   'You don’t need to be original. Most things have been done before. \n\nWhat people are looking for is something fresh.  A novel take on something familiar.',
#   'https://twitter.com/arvidkahl/status/1579243854527877120',
#   33,
#   None],
#  [datetime.datetime(2022, 10, 9, 21, 54, tzinfo=datetime.timezone.utc),
#   1579228712548958208,
#   '@arsawatt Yeah, for most purposes, they are more than enough. Finding the gems where you can supplant them is where founders can strike gold.',
#   'https://twitter.com/arvidkahl/status/1579228712548958208',
#   4,
#   1579222831610880000],
#  [datetime.datetime(2022, 10, 9, 20, 57, 10, tzinfo=datetime.timezone.utc),
#   1579214411088424960,
#   'If people are building their own clunky solutions to a common problem with tools like Excel, Word, or even pen&amp;paper, you’re looking at a SaaS business waiting to happen.',
#   'https://twitter.com/arvidkahl/status/1579214411088424960',
#   70,
#   None],
#  [datetime.datetime(2022, 10, 9, 20, 31, 54, tzinfo=datetime.timezone.utc),
#   1579208050141179904,
#   '@hellostartupla I guess that’s true for some. But I also believe that some people delude themselves into thinking they love something when they don’t.',
#   'https://twitter.com/arvidkahl/status/1579208050141179904',
#   3,
#   1579130064926408705],
#  [datetime.datetime(2022, 10, 9, 19, 51, 36, tzinfo=datetime.timezone.utc),
#   1579197908779683840,
#   '@SoftwareSocPod This dog. https://t.co/MNBiHeukfN',
#   'https://twitter.com/arvidkahl/status/1579197908779683840',
#   3,
#   1579196645799231489],
#  [datetime.datetime(2022, 10, 9, 19, 29, 3, tzinfo=datetime.timezone.utc),
#   1579192234322579457,
#   '@MasroorEjaz I trust that some people will. And the more people do it, the more it gets normalized. But yes, you won’t get it all the time.',
#   'https://twitter.com/arvidkahl/status/1579192234322579457',
#   1,
#   1579177685334781953],
#  [datetime.datetime(2022, 10, 9, 17, 59, 11, tzinfo=datetime.timezone.utc),
#   1579169619004166145,
#   'If you want to leave a legacy, help others help themselves.',
#   'https://twitter.com/arvidkahl/status/1579169619004166145',
#   68,
#   None],
#  [datetime.datetime(2022, 10, 9, 16, 47, 20, tzinfo=datetime.timezone.utc),
#   1579151537812934656,
#   "@dr That's 100% why I am a miniature painter in my free time. Real things, tangibly crafted, and manually made look nice :D Such a different thing compared to virtual work.",
#   'https://twitter.com/arvidkahl/status/1579151537812934656',
#   2,
#   1579110859129118721],
#  [datetime.datetime(2022, 10, 9, 16, 46, 27, tzinfo=datetime.timezone.utc),
#   1579151314055200768,
#   "@onejasonknight Thanks so much for the shoutout! And yes, anyone working on product can benefit from an entrepreneurial mindset. It's always good to have a different perspective — makes it easier to take the birds-eye view.",
#   'https://twitter.com/arvidkahl/status/1579151314055200768',
#   5,
#   1579150545549291522],
#  [datetime.datetime(2022, 10, 9, 15, 35, 26, tzinfo=datetime.timezone.utc),
#   1579133445502291970,
#   "@akoskm @AngeZanetti Oh that's how I listen to podcasts too. When I walk the dog, I often have @mjwhansen and @leenyburger in my ears.",
#   'https://twitter.com/arvidkahl/status/1579133445502291970',
#   3,
#   1579132540170153984],
#  [datetime.datetime(2022, 10, 9, 15, 34, 58, tzinfo=datetime.timezone.utc),
#   1579133326384070657,
#   '@akoskm @AngeZanetti Right? :D',
#   'https://twitter.com/arvidkahl/status/1579133326384070657',
#   1,
#   1579123693451898880],
#  [datetime.datetime(2022, 10, 9, 15, 34, 27, tzinfo=datetime.timezone.utc),
#   1579133196691976201,
#   '@ShimalSweety Been thinking about this a lot recently!\n\nhttps://t.co/TZTqn9sTKf',
#   'https://twitter.com/arvidkahl/status/1579133196691976201',
#   5,
#   1579128460223528961],
#  [datetime.datetime(2022, 10, 9, 15, 10, 11, tzinfo=datetime.timezone.utc),
#   1579127088657108995,
#   'The antidote to hustle culture is building an intentionally calm business.',
#   'https://twitter.com/arvidkahl/status/1579127088657108995',
#   137,
#   None],
#  [datetime.datetime(2022, 10, 9, 14, 54, 35, tzinfo=datetime.timezone.utc),
#   1579123163040198656,
#   '@SlamingDev Her name is Biene!',
#   'https://twitter.com/arvidkahl/status/1579123163040198656',
#   1,
#   1579120746982346752],
#  [datetime.datetime(2022, 10, 9, 14, 49, 2, tzinfo=datetime.timezone.utc),
#   1579121768371204096,
#   "@akoskm @AngeZanetti Thank you so much!\n\nI never feel bad for making mistakes. Instead, I remember that, unlike everyone who shied away from the challenge, I ran into the wall head-first, got a little bump, but I learned something for sure that others are still only guessing at.\n\nKeep making 'em!",
#   'https://twitter.com/arvidkahl/status/1579121768371204096',
#   2,
#   1579118957252186112],
#  [datetime.datetime(2022, 10, 9, 12, 46, 11, tzinfo=datetime.timezone.utc),
#   1579090851619557379,
#   '@TheAmineAouragh @ikoichi @dagorenouf @threehourcoffee You mean @usefathom by @JackEllis and Paul Jarvis?',
#   'https://twitter.com/arvidkahl/status/1579090851619557379',
#   2,
#   1579088821349933057],
#  [datetime.datetime(2022, 10, 9, 12, 45, 37, tzinfo=datetime.timezone.utc),
#   1579090705892651009,
#   '@ikoichi Big fan of @usefathom, use it on all my sites.',
#   'https://twitter.com/arvidkahl/status/1579090705892651009',
#   8,
#   1579087497287581702],
#  [datetime.datetime(2022, 10, 9, 12, 38, 17, tzinfo=datetime.timezone.utc),
#   1579088863943102465,
#   '@DmytroKrasun Take the problem and validate it ;) The fun part is to go into communities and figure out if there is a critical mass of people who need that particular problem solved. Only after that would I continue.',
#   'https://twitter.com/arvidkahl/status/1579088863943102465',
#   1,
#   1579061385140768769],
#  [datetime.datetime(2022, 10, 9, 12, 27, 33, tzinfo=datetime.timezone.utc),
#   1579086163096526850,
#   '@pmhackr @DmytroKrasun It’s more about finding validation to assumed problems than working on unvalidated ones.\n\nIt’s a question of sourcing validation signals from communities and interacting with those who give them.',
#   'https://twitter.com/arvidkahl/status/1579086163096526850',
#   1,
#   1579084009124298754],
#  [datetime.datetime(2022, 10, 9, 11, 44, tzinfo=datetime.timezone.utc),
#   1579075202000252929,
#   '@bryhutch Well thank you! 🍁',
#   'https://twitter.com/arvidkahl/status/1579075202000252929',
#   1,
#   1579064490523791369],
#  [datetime.datetime(2022, 10, 9, 11, 43, 58, tzinfo=datetime.timezone.utc),
#   1579075191426396160,
#   '@rukka_nova Neither I or the dog can catch them ;)',
#   'https://twitter.com/arvidkahl/status/1579075191426396160',
#   1,
#   1579069342922461184],
#  [datetime.datetime(2022, 10, 9, 10, 46, 29, tzinfo=datetime.timezone.utc),
#   1579060725779075072,
#   'Good morning! Have a great Sunday! \n\nInstead of hustling too much, maybe stare at a few squirrels with your dog today? https://t.co/VcGOUKxoai',
#   'https://twitter.com/arvidkahl/status/1579060725779075072',
#   227,
#   None],
#  [datetime.datetime(2022, 10, 9, 10, 44, 32, tzinfo=datetime.timezone.utc),
#   1579060235188449280,
#   '@DmytroKrasun It’s definitely easier to solve problems that come pre-validated ;)',
#   'https://twitter.com/arvidkahl/status/1579060235188449280',
#   1,
#   1578697067903320064],
#  [datetime.datetime(2022, 10, 9, 1, 28, 10, tzinfo=datetime.timezone.utc),
#   1578920220370284544,
#   'Bootstrapping a business means saying "no" to the non-essential things. \n\nYour resources are limited, so you have to prioritize what has the biggest impact.',
#   'https://twitter.com/arvidkahl/status/1578920220370284544',
#   101,
#   None],
#  [datetime.datetime(2022, 10, 8, 20, 40, 10, tzinfo=datetime.timezone.utc),
#   1578847744441171968,
#   'Building a community?\n\nConsider this: https://t.co/JVm00tuYH2',
#   'https://twitter.com/arvidkahl/status/1578847744441171968',
#   51,
#   None],
#  [datetime.datetime(2022, 10, 8, 14, 34, 57, tzinfo=datetime.timezone.utc),
#   1578755833529524226,
#   '@VKhoroshkov https://t.co/71hzQ0I4mA',
#   'https://twitter.com/arvidkahl/status/1578755833529524226',
#   1,
#   1578750334440087552],
#  [datetime.datetime(2022, 10, 8, 10, 57, 56, tzinfo=datetime.timezone.utc),
#   1578701218716663808,
#   '@jmckinven @dagorenouf https://t.co/jyvrlI2WuJ',
#   'https://twitter.com/arvidkahl/status/1578701218716663808',
#   2,
#   1578514475430268928],
#  [datetime.datetime(2022, 10, 8, 10, 57, 21, tzinfo=datetime.timezone.utc),
#   1578701074554576902,
#   '@dagorenouf @jmckinven https://t.co/wAXC0ed1TI',
#   'https://twitter.com/arvidkahl/status/1578701074554576902',
#   4,
#   1578688508025540608],
#  [datetime.datetime(2022, 10, 8, 10, 51, 27, tzinfo=datetime.timezone.utc),
#   1578699588927574016,
#   '@pierresbaptiste It’s psychological trickery. That’s not necessarily bad, but it’s annoyingly formulaic.',
#   'https://twitter.com/arvidkahl/status/1578699588927574016',
#   3,
#   1578561840908406785],
#  [datetime.datetime(2022, 10, 8, 10, 50, 47, tzinfo=datetime.timezone.utc),
#   1578699419629015042,
#   '@rrmdp https://t.co/SPUD3J54hG',
#   'https://twitter.com/arvidkahl/status/1578699419629015042',
#   2,
#   1578697010550824961],
#  [datetime.datetime(2022, 10, 8, 1, 36, 48, tzinfo=datetime.timezone.utc),
#   1578560007066759168,
#   'I don’t want “7 reasons that will change my mind on topic X.”\n\nI want to hear a genuine, relatable, unexpected perspective on topic X.\n\nThinkboi listicle threads irritate me. This is not a subtweet, just a very frustrated rant.',
#   'https://twitter.com/arvidkahl/status/1578560007066759168',
#   57,
#   None],
#  [datetime.datetime(2022, 10, 7, 23, 58, 22, tzinfo=datetime.timezone.utc),
#   1578535233489874945,
#   '@kidgdzilla @threehourcoffee @adhdjesse And replies!',
#   'https://twitter.com/arvidkahl/status/1578535233489874945',
#   3,
#   1578535085933879296],
#  [datetime.datetime(2022, 10, 7, 22, 8, 7, tzinfo=datetime.timezone.utc),
#   1578507489284222977,
#   '@frantzfries @dvassallo Most of the confusion probably stems from the fact that in die VC world, most businesses still operate on the delay-revenue-until-market-domination model. I certainly assumed that you were talking about the revenue-first bootstrapped world.',
#   'https://twitter.com/arvidkahl/status/1578507489284222977',
#   4,
#   1578507109331005440],
#  [datetime.datetime(2022, 10, 7, 22, 6, 36, tzinfo=datetime.timezone.utc),
#   1578507109331005440,
#   "@frantzfries @dvassallo I think this is exactly what many people from the indie founder community interpret your tweet to convey. If it's just an observation with no generalization intent, then we have a misunderstanding on our hands.\n\nBut hey, thanks for engaging with me here. Very kind of you.",
#   'https://twitter.com/arvidkahl/status/1578507109331005440',
#   4,
#   1578505483438022657],
#  [datetime.datetime(2022, 10, 7, 22, 0, 56, tzinfo=datetime.timezone.utc),
#   1578505680952365057,
#   "@alex___banks I initially wanted to quote this saying that this reminded me of my junior years, but then I remembered that this has never changed.\n\nIt's a common developer issue, for sure. We have many tools that can be abused to wrongly implement weird solutions :D",
#   'https://twitter.com/arvidkahl/status/1578505680952365057',
#   1,
#   1578504769726865408],
#  [datetime.datetime(2022, 10, 7, 21, 39, 44, tzinfo=datetime.timezone.utc),
#   1578500346745217024,
#   '@frantzfries @dvassallo True, shouldn’t have generalized. The observation is not wrong, but it seems to imply something ;)\n\nDo you think the Figma model can be generalized so that it would allow self-funded independent founders to sustain their businesses?',
#   'https://twitter.com/arvidkahl/status/1578500346745217024',
#   4,
#   1578495373894508544],
#  [datetime.datetime(2022, 10, 7, 20, 47, 9, tzinfo=datetime.timezone.utc),
#   1578487113015664641,
#   '@dvassallo @frantzfries Thanks for pointing this out. People preventing founders from charging money (in the hopes of becoming an outlier) are dangerous.',
#   'https://twitter.com/arvidkahl/status/1578487113015664641',
#   15,
#   1578457880759775232],
#  [datetime.datetime(2022, 10, 7, 20, 12, 13, tzinfo=datetime.timezone.utc),
#   1578478324149497856,
#   "What a powerful and relatable first episode!\n\n@jmckinven and @dagorenouf talk about their projects, their challenges —mental and physical— and how they tackle the daily woes of indie hacking. \n\nThis is how you build in public.\n\nTune in; it's spectacular.\n\nhttps://t.co/qW2Xov4MPQ https://t.co/Cl7FUA0NtP",
#   'https://twitter.com/arvidkahl/status/1578478324149497856',
#   40,
#   None],
#  [datetime.datetime(2022, 10, 7, 19, 22, 39, tzinfo=datetime.timezone.utc),
#   1578465849748254720,
#   'Oh, two of my favorite people are starting a podcast together.\n\nThis one s going right into my Overcast rotation. https://t.co/Cl7FUA0NtP',
#   'https://twitter.com/arvidkahl/status/1578465849748254720',
#   7,
#   None],
#  [datetime.datetime(2022, 10, 7, 18, 36, 44, tzinfo=datetime.timezone.utc),
#   1578454292276875265,
#   '@oliver_bloom_ It’s more of a full-time job than having a full-time job.',
#   'https://twitter.com/arvidkahl/status/1578454292276875265',
#   0,
#   1578145053641277441],
#  [datetime.datetime(2022, 10, 7, 16, 49, tzinfo=datetime.timezone.utc),
#   1578427181562093575,
#   'UX concepts where nothing could ever potentially go wrong :D https://t.co/6Ne84DhX0e',
#   'https://twitter.com/arvidkahl/status/1578427181562093575',
#   18,
#   None],
#  [datetime.datetime(2022, 10, 7, 16, 41, 46, tzinfo=datetime.timezone.utc),
#   1578425360513142785,
#   '@mattwensing The fact that you made a tool that makes enterprise sales better, easier, and more approachable for individual founders makes me very, VERY happy.',
#   'https://twitter.com/arvidkahl/status/1578425360513142785',
#   2,
#   1578400020100956162],
#  [datetime.datetime(2022, 10, 7, 16, 39, 18, tzinfo=datetime.timezone.utc),
#   1578424740116541440,
#   '@JamesTimmins Are they generally hard to reach or just for you on this issue? Any chance you can find an alternative channel to reach them on? Also, can you get your existing users to reach out to them instead? :)',
#   'https://twitter.com/arvidkahl/status/1578424740116541440',
#   0,
#   1578411946226819072],
#  [datetime.datetime(2022, 10, 7, 15, 33, 27, tzinfo=datetime.timezone.utc),
#   1578408167410745344,
#   "If you would like to see articles like this in your inbox as soon as they're out, consider signing up for my newsletter. \n\nI'd appreciate it, and 5350 other founders already have my articles delivered to them every Friday.\n\nhttps://t.co/BLLxRvIb5j",
#   'https://twitter.com/arvidkahl/status/1578408167410745344',
#   3,
#   1578408165707845637],
#  [datetime.datetime(2022, 10, 7, 15, 33, 26, tzinfo=datetime.timezone.utc),
#   1578408165707845637,
#   "And it's on YouTube:\n\nhttps://t.co/je5X6WIysx",
#   'https://twitter.com/arvidkahl/status/1578408165707845637',
#   1,
#   1578408164265193472],
#  [datetime.datetime(2022, 10, 7, 15, 33, 26, tzinfo=datetime.timezone.utc),
#   1578408164265193472,
#   'This is also available as a podcast episode:\n\nhttps://t.co/LaM0ai6QrS',
#   'https://twitter.com/arvidkahl/status/1578408164265193472',
#   1,
#   1578408161870024707],
#  [datetime.datetime(2022, 10, 7, 15, 33, 25, tzinfo=datetime.timezone.utc),
#   1578408161870024707,
#   "Now, how do you validate that you're working on the right solution?\n\nIn this article, I present the concierge approach and how it can help you validate your solution.\n\nhttps://t.co/QOIl0Yo0C5",
#   'https://twitter.com/arvidkahl/status/1578408161870024707',
#   2,
#   1578408160079093769],
#  [datetime.datetime(2022, 10, 7, 15, 33, 25, tzinfo=datetime.timezone.utc),
#   1578408160079093769,
#   "Thankfully, integration opportunities exist. From @zapier to open-source libraries, you have access to a plethora of solutions to ingest and output just the formats and systems you need. Abstraction and a focus on integration allow you to deal with your customers' limitations.",
#   'https://twitter.com/arvidkahl/status/1578408160079093769',
#   1,
#   1578408158690672640],
#  [datetime.datetime(2022, 10, 7, 15, 33, 25, tzinfo=datetime.timezone.utc),
#   1578408158690672640,
#   'Ask yourself: "to do this job, what do they have to work with, and what do they need the result to look like?"\n\nIf you can offer a solution that takes these inputs and produces the outputs, you have a potential business. If your solution needs extra steps, you have a problem.',
#   'https://twitter.com/arvidkahl/status/1578408158690672640',
#   1,
#   1578408156320915456],
#  [datetime.datetime(2022, 10, 7, 15, 33, 24, tzinfo=datetime.timezone.utc),
#   1578408156320915456,
#   "Your solution needs to resonate with your prospects.\n\nMost of all: the solution you come up with needs to fit into existing workflows. If you offer a service that people have to change their whole way of doing business for, they won't buy. Learn about their inputs &amp; outputs.",
#   'https://twitter.com/arvidkahl/status/1578408156320915456',
#   1,
#   1578408155037450243],
#  [datetime.datetime(2022, 10, 7, 15, 33, 24, tzinfo=datetime.timezone.utc),
#   1578408155037450243,
#   'A solution, by the way, is not a finished product. A solution is how you want to solve a problem in general — a step-by-step process, really. \n\nA product is a specific technical implementation of that solution.\n\nGet the solution right before you build a product people will buy.',
#   'https://twitter.com/arvidkahl/status/1578408155037450243',
#   2,
#   1578408153766559751],
#  [datetime.datetime(2022, 10, 7, 15, 33, 23, tzinfo=datetime.timezone.utc),
#   1578408153766559751,
#   'It starts with understanding the Jobs to be Done. You\'re not just solving a problem. You\'re solving a problem in the context of many other things: goals, processes, and "how things are done around here."\n\nYour solution needs to fit in.',
#   'https://twitter.com/arvidkahl/status/1578408153766559751',
#   3,
#   1578407231430746112],
#  [datetime.datetime(2022, 10, 7, 15, 29, 44, tzinfo=datetime.timezone.utc),
#   1578407231430746112,
#   'You want to build a SaaS.\nYou found your market.\nYou found a critical problem.\n\nNow what? Build the product? \n\nWRONG. Before you jump into your code editor, you have to scope and validate your solution. If you skip this, you might waste weeks of your time.\n\nSo, how is this done? https://t.co/AEKz9nOznM',
#   'https://twitter.com/arvidkahl/status/1578407231430746112',
#   17,
#   None],
#  [datetime.datetime(2022, 10, 7, 15, 28, 39, tzinfo=datetime.timezone.utc),
#   1578406962802237440,
#   "If you would like to see articles like this in your inbox as soon as they're out, consider signing up for my newsletter. \n\nI'd appreciate it, and 4632 other founders already have my articles delivered to them every Friday.\n\nhttps://t.co/BLLxRvZLWR",
#   'https://twitter.com/arvidkahl/status/1578406962802237440',
#   0,
#   1578406960856289280],
#  [datetime.datetime(2022, 10, 7, 15, 28, 39, tzinfo=datetime.timezone.utc),
#   1578406960856289280,
#   "And it's on YouTube:\n\nhttps://t.co/je5X6WIysx",
#   'https://twitter.com/arvidkahl/status/1578406960856289280',
#   0,
#   1578406959161778176],
#  [datetime.datetime(2022, 10, 7, 15, 28, 39, tzinfo=datetime.timezone.utc),
#   1578406959161778176,
#   'This is also available as a podcast episode:\n\nhttps://t.co/LaM0ai6iCk',
#   'https://twitter.com/arvidkahl/status/1578406959161778176',
#   0,
#   1578406957421150212],
#  [datetime.datetime(2022, 10, 7, 15, 28, 38, tzinfo=datetime.timezone.utc),
#   1578406957421150212,
#   "Now, how do you validate that you're working on the right solution?\n\nIn this article, I present the concierge approach and how it can help you validate your solution.\n\nhttps://t.co/QOIl0Yo0C5",
#   'https://twitter.com/arvidkahl/status/1578406957421150212',
#   0,
#   1578406955864887296],
#  [datetime.datetime(2022, 10, 7, 15, 28, 38, tzinfo=datetime.timezone.utc),
#   1578406955864887296,
#   "Thankfully, integration opportunities exist. From @zapier to open-source libraries, you have access to a plethora of solutions to ingest and output just the formats and systems you need. Abstraction and a focus on integration allow you to deal with your customers' limitations.",
#   'https://twitter.com/arvidkahl/status/1578406955864887296',
#   0,
#   1578406953969192961],
#  [datetime.datetime(2022, 10, 7, 15, 28, 37, tzinfo=datetime.timezone.utc),
#   1578406953969192961,
#   'Ask yourself: "to do this job, what do they have to work with, and what do they need the result to look like?"\n\nIf you can offer a solution that takes these inputs and produces the outputs, you have a potential business. If your solution needs extra steps, you have a problem.',
#   'https://twitter.com/arvidkahl/status/1578406953969192961',
#   0,
#   1578406952975073281],
#  [datetime.datetime(2022, 10, 7, 15, 28, 37, tzinfo=datetime.timezone.utc),
#   1578406952975073281,
#   "Your solution needs to resonate with your prospects.\n\nMost of all: the solution you come up with needs to fit into existing workflows. If you offer a service that people have to change their whole way of doing business for, they won't buy. Learn about their inputs &amp; outputs.",
#   'https://twitter.com/arvidkahl/status/1578406952975073281',
#   0,
#   1578406951087587328],
#  [datetime.datetime(2022, 10, 7, 15, 28, 37, tzinfo=datetime.timezone.utc),
#   1578406951087587328,
#   'A solution, by the way, is not a finished product. A solution is how you want to solve a problem in general — a step-by-step process, really. \n\nA product is a specific technical implementation of that solution.\n\nGet the solution right before you build a product people will buy.',
#   'https://twitter.com/arvidkahl/status/1578406951087587328',
#   0,
#   1578406948218732544],
#  [datetime.datetime(2022, 10, 7, 15, 28, 36, tzinfo=datetime.timezone.utc),
#   1578406948218732544,
#   'It starts with understanding the Jobs to be Done. You\'re not just solving a problem. You\'re solving a problem in the context of many other things: goals, processes, and "how things are done around here."\n\nYour solution needs to fit in.',
#   'https://twitter.com/arvidkahl/status/1578406948218732544',
#   2,
#   1578406946939379714],
#  [datetime.datetime(2022, 10, 7, 15, 18, 10, tzinfo=datetime.timezone.utc),
#   1578404323255631877,
#   '@rrmdp @SimonHoiberg Some of them might be!',
#   'https://twitter.com/arvidkahl/status/1578404323255631877',
#   1,
#   1578394138352959490],
#  [datetime.datetime(2022, 10, 7, 15, 1, 15, tzinfo=datetime.timezone.utc),
#   1578400065063985154,
#   '@SimonHoiberg - reformulation\n- consistency checking\n- sentiment analysis\n- prose simplification\n- self-publishing tools\n- automatic content referencing\n\nLots of interesting fields :)',
#   'https://twitter.com/arvidkahl/status/1578400065063985154',
#   9,
#   1578394890110648325],
#  [datetime.datetime(2022, 10, 7, 14, 23, 14, tzinfo=datetime.timezone.utc),
#   1578390497248378880,
#   'I wonder if they have any credentials. https://t.co/xnONA39wTr',
#   'https://twitter.com/arvidkahl/status/1578390497248378880',
#   11,
#   None],
#  [datetime.datetime(2022, 10, 7, 14, 14, 51, tzinfo=datetime.timezone.utc),
#   1578388390088785920,
#   "@SimonHoiberg I'd experiment my way through many writing tools until I found one that makes a lot of difference.",
#   'https://twitter.com/arvidkahl/status/1578388390088785920',
#   12,
#   1578386243381071878],
#  [datetime.datetime(2022, 10, 7, 13, 34, 21, tzinfo=datetime.timezone.utc),
#   1578378195853889538,
#   "@NafetsWirth @agazdecki Couldn't be more aligned :D",
#   'https://twitter.com/arvidkahl/status/1578378195853889538',
#   2,
#   1578377964768600064],
#  [datetime.datetime(2022, 10, 7, 13, 31, 37, tzinfo=datetime.timezone.utc),
#   1578377509506269185,
#   '@kylegawley Listen to this man.',
#   'https://twitter.com/arvidkahl/status/1578377509506269185',
#   1,
#   1578294576485322752],
#  [datetime.datetime(2022, 10, 7, 13, 18, 44, tzinfo=datetime.timezone.utc),
#   1578374266566778881,
#   '@adrian_horning_ Thanks for sharing! I know this feeling, and freelancing is a great idea. Having the freedom to do things that need to be done to get ahead is why I love entrepreneurship :D',
#   'https://twitter.com/arvidkahl/status/1578374266566778881',
#   6,
#   1578165614497001474],
#  [datetime.datetime(2022, 10, 7, 13, 13, 15, tzinfo=datetime.timezone.utc),
#   1578372886989262848,
#   'My new video on Finding and Validating Solutions for Calm SaaS Businesses is out!\n\nhttps://t.co/je5X6WJ6i5',
#   'https://twitter.com/arvidkahl/status/1578372886989262848',
#   11,
#   None],
#  [datetime.datetime(2022, 10, 7, 13, 2, 11, tzinfo=datetime.timezone.utc),
#   1578370099693719555,
#   'Having a wall of love is a powerful motivator. https://t.co/hUzaJV7bfJ',
#   'https://twitter.com/arvidkahl/status/1578370099693719555',
#   10,
#   None],
#  [datetime.datetime(2022, 10, 7, 13, 0, 5, tzinfo=datetime.timezone.utc),
#   1578369571173683200,
#   '★ Just published a new episode of The Bootstrapped Founder: 157: Solution Exploration for Calm SaaS Businesses. Listen: https://t.co/LaM0ai6iCk',
#   'https://twitter.com/arvidkahl/status/1578369571173683200',
#   5,
#   None],
#  [datetime.datetime(2022, 10, 7, 12, 41, 24, tzinfo=datetime.timezone.utc),
#   1578364872508592128,
#   '@agazdecki https://t.co/6iWfNDG4HX',
#   'https://twitter.com/arvidkahl/status/1578364872508592128',
#   2,
#   1578361788533350400],
#  [datetime.datetime(2022, 10, 7, 12, 19, 14, tzinfo=datetime.timezone.utc),
#   1578359291769425920,
#   "And creator-friendly! They have been sponsoring my podcast for a year now. And they're not stopping!",
#   'https://twitter.com/arvidkahl/status/1578359291769425920',
#   5,
#   1578352990603419649],
#  [datetime.datetime(2022, 10, 7, 12, 9, 8, tzinfo=datetime.timezone.utc),
#   1578356749039374336,
#   "The things we have to invent to solve problems we shouldn't have 🤣 https://t.co/KKbEbx60f3",
#   'https://twitter.com/arvidkahl/status/1578356749039374336',
#   25,
#   None],
#  [datetime.datetime(2022, 10, 7, 12, 7, 5, tzinfo=datetime.timezone.utc),
#   1578356234905735169,
#   '@HeyJimBurgess Hey Jim! :D',
#   'https://twitter.com/arvidkahl/status/1578356234905735169',
#   2,
#   1578356048305561602],
#  [datetime.datetime(2022, 10, 7, 12, 2, 53, tzinfo=datetime.timezone.utc),
#   1578355179963179009,
#   '@ItsKieranDrew Oh yeah, that stuff is magical.\n\nWhen your conscious brain decides to block your unconscious brain :D',
#   'https://twitter.com/arvidkahl/status/1578355179963179009',
#   2,
#   1578351974860611584],
#  [datetime.datetime(2022, 10, 7, 11, 54, 11, tzinfo=datetime.timezone.utc),
#   1578352990603419649,
#   'How I love MicroAcquire. What a community-centric business. https://t.co/InIFfiUurQ',
#   'https://twitter.com/arvidkahl/status/1578352990603419649',
#   45,
#   None],
#  [datetime.datetime(2022, 10, 7, 11, 47, 48, tzinfo=datetime.timezone.utc),
#   1578351382889123842,
#   "Whenever I open my laptop, I am greeted by the invitation to many distractions. Emails, YouTube thumbnails, social feeds.\n\nEver day, it's a choice. to get started with what matters.\n\nWhat matters to you today?",
#   'https://twitter.com/arvidkahl/status/1578351382889123842',
#   46,
#   None],
#  [datetime.datetime(2022, 10, 7, 11, 12, 19, tzinfo=datetime.timezone.utc),
#   1578342452850659328,
#   'This is eerily relatable. https://t.co/NH6ZoEYcZx',
#   'https://twitter.com/arvidkahl/status/1578342452850659328',
#   29,
#   None],
#  [datetime.datetime(2022, 10, 7, 10, 33, 19, tzinfo=datetime.timezone.utc),
#   1578332637130739713,
#   '@SamHartmannCom Important part of coming up with the idea in the first place!',
#   'https://twitter.com/arvidkahl/status/1578332637130739713',
#   1,
#   1578280811467444224],
#  [datetime.datetime(2022, 10, 7, 0, 34, 31, tzinfo=datetime.timezone.utc),
#   1578181944780947457,
#   '@gpfunke1 Yup! https://t.co/xlD0lQQ3XB',
#   'https://twitter.com/arvidkahl/status/1578181944780947457',
#   0,
#   1578145280360615938],
#  [datetime.datetime(2022, 10, 6, 23, 27, 11, tzinfo=datetime.timezone.utc),
#   1578165000878923776,
#   'If you run out of creative energy, find inspiration in your past work. \n\nEvery successful painter paints the same picture over and over again until it’s a masterpiece.',
#   'https://twitter.com/arvidkahl/status/1578165000878923776',
#   59,
#   None],
#  [datetime.datetime(2022, 10, 6, 21, 49, 31, tzinfo=datetime.timezone.utc),
#   1578140420395204609,
#   'My Apple TV gets me 100%. 🤣 https://t.co/BtAPpD0mOZ',
#   'https://twitter.com/arvidkahl/status/1578140420395204609',
#   12,
#   None],
#  [datetime.datetime(2022, 10, 6, 21, 2, 8, tzinfo=datetime.timezone.utc),
#   1578128495754051607,
#   "@amandanat Please don't spill the secret to why I have so much fun writing :P",
#   'https://twitter.com/arvidkahl/status/1578128495754051607',
#   2,
#   1578042898422956034],
#  [datetime.datetime(2022, 10, 6, 20, 57, 3, tzinfo=datetime.timezone.utc),
#   1578127215803473921,
#   '@joe_ashwell Back when zipping your whole server directory was version control',
#   'https://twitter.com/arvidkahl/status/1578127215803473921',
#   15,
#   1577773512151834624],
#  [datetime.datetime(2022, 10, 6, 20, 53, 15, tzinfo=datetime.timezone.utc),
#   1578126259917389838,
#   "Anyway.\n\nFind your founder friends. Talk to them. Share your ups and your downs.\n\nYou'll be better off for it.\n\nAnd then, later, find a way to bridge the knowledge gap with your non-founder peers.",
#   'https://twitter.com/arvidkahl/status/1578126259917389838',
#   6,
#   1578126257744740369],
#  [datetime.datetime(2022, 10, 6, 20, 53, 14, tzinfo=datetime.timezone.utc),
#   1578126257744740369,
#   "It's emotional labor to re-educate people — and it's on them to seek new insights, not on you to provide them at all costs.\n\nYou don't need permission to take care of your own mental health first.",
#   'https://twitter.com/arvidkahl/status/1578126257744740369',
#   4,
#   1578126255010054144],
#  [datetime.datetime(2022, 10, 6, 20, 53, 14, tzinfo=datetime.timezone.utc),
#   1578126255010054144,
#   "But don't educate them while you're going through something yourself. It's not your job to deconstruct someone else's problems while you are dealing with your own.",
#   'https://twitter.com/arvidkahl/status/1578126255010054144',
#   4,
#   1578126252845764608],
#  [datetime.datetime(2022, 10, 6, 20, 53, 13, tzinfo=datetime.timezone.utc),
#   1578126252845764608,
#   "Don't demonize the ignorant, either. They don't know any better. Like you, they've been told stories about business owners their whole life, and they have a library full of resentments and preconceived notions that color their world.\n\nHelp them understand your reality.",
#   'https://twitter.com/arvidkahl/status/1578126252845764608',
#   6,
#   1578126250547154944],
#  [datetime.datetime(2022, 10, 6, 20, 53, 12, tzinfo=datetime.timezone.utc),
#   1578126250547154944,
#   "One way out is to find solace and support in the founder community. Find your peers and engage them, and you will quickly see that you're not alone with your trials and tribulations. \n\nThousands of people go through all of this with you, right at this moment.",
#   'https://twitter.com/arvidkahl/status/1578126250547154944',
#   6,
#   1578126248190025730],
#  [datetime.datetime(2022, 10, 6, 20, 53, 12, tzinfo=datetime.timezone.utc),
#   1578126248190025730,
#   "And consequently, they belittle your problems or ignore your cries for help — they just don't have a frame of reference for your very real and very legitimate problems.\n\nIt can be very painful to find this ignorance in your family or even your partner.",
#   'https://twitter.com/arvidkahl/status/1578126248190025730',
#   5,
#   1578126245581258763],
#  [datetime.datetime(2022, 10, 6, 20, 53, 11, tzinfo=datetime.timezone.utc),
#   1578126245581258763,
#   'A consequence of most people not understanding what an entrepreneur does is that if you as a founder feel overwhelmed, you have very few people to talk to.\n\nFor most, "running a business" is perceived to be a stress-free, amazing life. Your struggles don\'t make sense to them. 👇',
#   'https://twitter.com/arvidkahl/status/1578126245581258763',
#   31,
#   None],
#  [datetime.datetime(2022, 10, 6, 20, 13, 19, tzinfo=datetime.timezone.utc),
#   1578116213745614857,
#   '@NafetsWirth @TimothyBramlett @sbalen Yes! Also, @JohnWarrillow, author of Built to Sell has written a third book called The Art of Selling Your Business. Read that one too, in preparation of any kind of sale!',
#   'https://twitter.com/arvidkahl/status/1578116213745614857',
#   3,
#   1578115923717898241],
#  [datetime.datetime(2022, 10, 6, 19, 54, 34, tzinfo=datetime.timezone.utc),
#   1578111493471608832,
#   '@Dominus_Kelvin Yes! The goal is to build relationship, not to "win."',
#   'https://twitter.com/arvidkahl/status/1578111493471608832',
#   1,
#   1578107435973480448],
#  [datetime.datetime(2022, 10, 6, 19, 30, 26, tzinfo=datetime.timezone.utc),
#   1578105419481743361,
#   "And here's the YouTube channel in question — in case you want to support me ;)\n\nhttps://t.co/lBWJ8j0BWk",
#   'https://twitter.com/arvidkahl/status/1578105419481743361',
#   5,
#   1578105240800595968],
#  [datetime.datetime(2022, 10, 6, 19, 29, 43, tzinfo=datetime.timezone.utc),
#   1578105240800595968,
#   'A single sentence of this would have made my day. The whole comment made my week.\n\nIf you want to empoy one of the most high-leverage ways of motivating a person, reply to their work. Leave a comment. Send an email back.\n\nIt matters.',
#   'https://twitter.com/arvidkahl/status/1578105240800595968',
#   12,
#   1578105238888013824],
#  [datetime.datetime(2022, 10, 6, 19, 29, 43, tzinfo=datetime.timezone.utc),
#   1578105238888013824,
#   'As a creator, this is what I work for. https://t.co/3D33pzgc7p',
#   'https://twitter.com/arvidkahl/status/1578105238888013824',
#   32,
#   None],
#  [datetime.datetime(2022, 10, 6, 18, 55, 26, tzinfo=datetime.timezone.utc),
#   1578096609950257157,
#   '@g3Mo @DescriptApp https://t.co/MRBGUQOFNL',
#   'https://twitter.com/arvidkahl/status/1578096609950257157',
#   1,
#   1578093044212985856],
#  [datetime.datetime(2022, 10, 6, 18, 50, 2, tzinfo=datetime.timezone.utc),
#   1578095254128902144,
#   "@NafetsWirth Not sure what I dislike more: Google's kraken of a portfolio or the predatory lawyers. Both equally bad.",
#   'https://twitter.com/arvidkahl/status/1578095254128902144',
#   12,
#   1577991611727970305],
#  [datetime.datetime(2022, 10, 6, 18, 17, 7, tzinfo=datetime.timezone.utc),
#   1578086966976970777,
#   '@shalom_luke @DescriptApp It’s incredibly awesome. Producing my edited video for this week took me less than an hour. Side effects: a fully edited podcast episode, accurate subtitles, several sample clips of the episode. @DescriptApp is the highest-leverage SaaS I use. https://t.co/i8SIr8j93b',
#   'https://twitter.com/arvidkahl/status/1578086966976970777',
#   2,
#   1578085570785542146],
#  [datetime.datetime(2022, 10, 6, 18, 15, 15, tzinfo=datetime.timezone.utc),
#   1578086501065293830,
#   '@mcavaliere Thank you kindly!',
#   'https://twitter.com/arvidkahl/status/1578086501065293830',
#   1,
#   1578085915674673166],
#  [datetime.datetime(2022, 10, 6, 18, 7, 10, tzinfo=datetime.timezone.utc),
#   1578084465716465666,
#   '@cnu I appreciate it :)',
#   'https://twitter.com/arvidkahl/status/1578084465716465666',
#   1,
#   1578082286561419264],
#  [datetime.datetime(2022, 10, 6, 17, 59, 15, tzinfo=datetime.timezone.utc),
#   1578082471287062532,
#   '@InTake_Anthony @MeetKevon @DescriptApp Oh I love this perspective!! I really have low pressure with one piece of major content a week. I work on it all week, of course, but I don’t have to cut corners. Thanks so much for this!',
#   'https://twitter.com/arvidkahl/status/1578082471287062532',
#   1,
#   1578075304098152448],
#  [datetime.datetime(2022, 10, 6, 17, 50, 36, tzinfo=datetime.timezone.utc),
#   1578080297391906817,
#   "If you would like to see articles like this in your inbox as soon as they're out, consider signing up for my newsletter. \n\nhttps://t.co/BLLxRvIb5j",
#   'https://twitter.com/arvidkahl/status/1578080297391906817',
#   4,
#   1578080295135371264],
#  [datetime.datetime(2022, 10, 6, 17, 50, 36, tzinfo=datetime.timezone.utc),
#   1578080295135371264,
#   'Last week, my newsletter went out to 5270 readers.\n\nThis week —18 hours before sending it out— 70 additional creators and founders will learn how to find and validate SaaS solutions in a calm way.\n\nI am so happy :D https://t.co/VsysDBYzQx',
#   'https://twitter.com/arvidkahl/status/1578080295135371264',
#   13,
#   None],
#  [datetime.datetime(2022, 10, 6, 16, 20, 58, tzinfo=datetime.timezone.utc),
#   1578057740852813824,
#   "@ZekeAranyLucas @DescriptApp Haven't used it yet! Will report back if I ever do!",
#   'https://twitter.com/arvidkahl/status/1578057740852813824',
#   0,
#   1578057243504820224],
#  [datetime.datetime(2022, 10, 6, 16, 19, 19, tzinfo=datetime.timezone.utc),
#   1578057323062480896,
#   "@onejasonknight @DescriptApp Ha, we're in the same boat, Jason :D",
#   'https://twitter.com/arvidkahl/status/1578057323062480896',
#   1,
#   1578056935152271361],
#  [datetime.datetime(2022, 10, 6, 16, 17, 55, tzinfo=datetime.timezone.utc),
#   1578056969683976198,
#   "@Dominus_Kelvin @DescriptApp This week's episode is about Solution Validation for Calm SaaS businesses :)",
#   'https://twitter.com/arvidkahl/status/1578056969683976198',
#   1,
#   1578046979250216965],
#  [datetime.datetime(2022, 10, 6, 15, 34, 7, tzinfo=datetime.timezone.utc),
#   1578045948894248961,
#   '@MeetKevon @DescriptApp I think I found something I really enjoy doing. Interacting with thousands of people while being cozy and alone in my basement :D',
#   'https://twitter.com/arvidkahl/status/1578045948894248961',
#   8,
#   1578045276233031681],
#  [datetime.datetime(2022, 10, 6, 15, 29, 44, tzinfo=datetime.timezone.utc),
#   1578044847017132032,
#   "Just recorded episode 157 of my podcast.\n\nEvery time I finish recording, I am in awe of the fact that I get to do this every week. It's a blast :D\n\nNow, it's time to fire up @DescriptApp and get editing.",
#   'https://twitter.com/arvidkahl/status/1578044847017132032',
#   45,
#   None],
#  [datetime.datetime(2022, 10, 6, 11, 19, 35, tzinfo=datetime.timezone.utc),
#   1577981894498701313,
#   '@faizalshap Thank you most kindly! 🥰',
#   'https://twitter.com/arvidkahl/status/1577981894498701313',
#   1,
#   1577914448991252480],
#  [datetime.datetime(2022, 10, 6, 1, 25, 10, tzinfo=datetime.timezone.utc),
#   1577832303509872645,
#   "The hard part about entrepreneurship is that even the right choices feel like highly risky gambles. Things take a while to show results, and if you can't handle this discomfort, you'll feel like you have no control.",
#   'https://twitter.com/arvidkahl/status/1577832303509872645',
#   104,
#   None],
#  [datetime.datetime(2022, 10, 5, 23, 31, 9, tzinfo=datetime.timezone.utc),
#   1577803610624253953,
#   'Competition is not a reason to scrap your plans.\n\nCompetition is a proof of concept. If anything, competition is a compelling reason to finally get started.',
#   'https://twitter.com/arvidkahl/status/1577803610624253953',
#   131,
#   None],
#  [datetime.datetime(2022, 10, 5, 23, 21, 14, tzinfo=datetime.timezone.utc),
#   1577801113822191618,
#   'This is commitment to the hobby. https://t.co/efMWvp6rjL',
#   'https://twitter.com/arvidkahl/status/1577801113822191618',
#   22,
#   None],
#  [datetime.datetime(2022, 10, 5, 20, 10, 11, tzinfo=datetime.timezone.utc),
#   1577753033483730972,
#   'The worst part is that students bring these notions (learning to the test, suppressing curiosity, defaulting to obedience) into an economic reality that desperately needs new ideas, creative thinkers, and experimental minds. https://t.co/i88ppco9r8',
#   'https://twitter.com/arvidkahl/status/1577753033483730972',
#   22,
#   None],
#  [datetime.datetime(2022, 10, 5, 16, 14, 6, tzinfo=datetime.timezone.utc),
#   1577693621620539393,
#   '@amandanat https://t.co/te5l9lSYiO',
#   'https://twitter.com/arvidkahl/status/1577693621620539393',
#   1,
#   1577688741019545600],
#  [datetime.datetime(2022, 10, 5, 15, 58, 34, tzinfo=datetime.timezone.utc),
#   1577689713938505730,
#   'Glad to see CeeJay safe in Turkey. Do I have any Indie Hacker friends in Istanbul that want to make a new friend? :) https://t.co/a9R8gpeIk3',
#   'https://twitter.com/arvidkahl/status/1577689713938505730',
#   42,
#   None],
#  [datetime.datetime(2022, 10, 5, 15, 48, 7, tzinfo=datetime.timezone.utc),
#   1577687084629901313,
#   '@nathell Thanks Daniel, awesome work!',
#   'https://twitter.com/arvidkahl/status/1577687084629901313',
#   0,
#   1577684964065394688],
#  [datetime.datetime(2022, 10, 5, 14, 34, 24, tzinfo=datetime.timezone.utc),
#   1577668531683999744,
#   '@mzrnsh Aww, thanks so much! 🥰',
#   'https://twitter.com/arvidkahl/status/1577668531683999744',
#   1,
#   1577664252059549699],
#  [datetime.datetime(2022, 10, 5, 14, 30, 46, tzinfo=datetime.timezone.utc),
#   1577667618248474629,
#   '🥰 https://t.co/mzmV978hJO',
#   'https://twitter.com/arvidkahl/status/1577667618248474629',
#   8,
#   None],
#  [datetime.datetime(2022, 10, 5, 14, 7, 58, tzinfo=datetime.timezone.utc),
#   1577661880247672836,
#   '@AndrewWHacks :D',
#   'https://twitter.com/arvidkahl/status/1577661880247672836',
#   0,
#   1577661722298503169],
#  [datetime.datetime(2022, 10, 5, 13, 37, 17, tzinfo=datetime.timezone.utc),
#   1577654159742058496,
#   '@SwayMolina This itself is a supportive message! :D\n\nBoundaries are important and often painful to learn. 100% agreed here!',
#   'https://twitter.com/arvidkahl/status/1577654159742058496',
#   2,
#   1577653692324519938],
#  [datetime.datetime(2022, 10, 5, 13, 32, 32, tzinfo=datetime.timezone.utc),
#   1577652963220283394,
#   "@rmcomplexity Makes sense to me. I love that this stuff is so novel that we're still debating the terms in which we talk about it.",
#   'https://twitter.com/arvidkahl/status/1577652963220283394',
#   1,
#   1577651796725698561],
#  [datetime.datetime(2022, 10, 5, 13, 18, 12, tzinfo=datetime.timezone.utc),
#   1577649356706119681,
#   '@rmcomplexity That said, all art is art.\n\nAnd just like sous-vide cooking is definitely cooking, AI-augmented art is a specific approach with specific tooling.',
#   'https://twitter.com/arvidkahl/status/1577649356706119681',
#   0,
#   1577649072428777472],
#  [datetime.datetime(2022, 10, 5, 13, 17, 4, tzinfo=datetime.timezone.utc),
#   1577649072428777472,
#   '@rmcomplexity I know lots of writers and illustrators who have massive bookshelves full of picture books and reference magazines. Still, the spark to recombine those inputs into something new happens within the artist.\n\nWith AI augmentation, some of that spark gets outsourced to the AI.',
#   'https://twitter.com/arvidkahl/status/1577649072428777472',
#   0,
#   1577648809185771522],
#  [datetime.datetime(2022, 10, 5, 13, 16, 2, tzinfo=datetime.timezone.utc),
#   1577648809185771522,
#   '@rmcomplexity Inspiration is a super-interesting topic! It\'s definitely art all by itself, too. It just has a new quality to it when it comes to the level of composition — everything you google is "prior art," but a Midjourney creation is something that has never been there before.',
#   'https://twitter.com/arvidkahl/status/1577648809185771522',
#   0,
#   1577648372823080961],
#  [datetime.datetime(2022, 10, 5, 13, 6, 11, tzinfo=datetime.timezone.utc),
#   1577646331082022912,
#   'Do you want to surround yourself with kind and supportive people?\n\nAttract them by being kind and supportive.',
#   'https://twitter.com/arvidkahl/status/1577646331082022912',
#   113,
#   None],
#  [datetime.datetime(2022, 10, 5, 13, 4, 22, tzinfo=datetime.timezone.utc),
#   1577645873458302980,
#   'AI-Augmented Art is going to be incredibly huge. https://t.co/d48QvrEig0',
#   'https://twitter.com/arvidkahl/status/1577645873458302980',
#   8,
#   None],
#  [datetime.datetime(2022, 10, 5, 12, 41, 58, tzinfo=datetime.timezone.utc),
#   1577640236259184640,
#   "@spacesformac It's certainly legal and socially obligated to dose your body with potent chemicals every day to do your regular work.",
#   'https://twitter.com/arvidkahl/status/1577640236259184640',
#   0,
#   1577639921757523969],
#  [datetime.datetime(2022, 10, 5, 12, 37, 57, tzinfo=datetime.timezone.utc),
#   1577639226417369089,
#   'And now, let me get a coffee.',
#   'https://twitter.com/arvidkahl/status/1577639226417369089',
#   21,
#   1577639108020736002],
#  [datetime.datetime(2022, 10, 5, 12, 37, 29, tzinfo=datetime.timezone.utc),
#   1577639108020736002,
#   'It\'s kind of bizarre that in the morning, we drink coffee to "perform," and then, when the work is done, we drink alcohol to "relax."\n\nOur baseline function should be enough to do the things that matter. Yet we fall into this social spiral of drugging our attention into place. :/',
#   'https://twitter.com/arvidkahl/status/1577639108020736002',
#   37,
#   None],
#  [datetime.datetime(2022, 10, 5, 12, 4, 45, tzinfo=datetime.timezone.utc),
#   1577630873545056257,
#   '@mjwhansen Better make sure :D',
#   'https://twitter.com/arvidkahl/status/1577630873545056257',
#   1,
#   1577575837951483905],
#  [datetime.datetime(2022, 10, 5, 11, 58, 58, tzinfo=datetime.timezone.utc),
#   1577629418343714816,
#   '@storyangled Yes, it\'s a very selfish and net-negative perspective even. It could be "empowering" or "aligning" — but it\'s hacking instead.',
#   'https://twitter.com/arvidkahl/status/1577629418343714816',
#   1,
#   1577628660634472448],
#  [datetime.datetime(2022, 10, 5, 11, 54, 13, tzinfo=datetime.timezone.utc),
#   1577628220144472068,
#   'I love this. \n\nhttps://t.co/JfjddFo8ag',
#   'https://twitter.com/arvidkahl/status/1577628220144472068',
#   18,
#   None],
#  [datetime.datetime(2022, 10, 5, 10, 16, tzinfo=datetime.timezone.utc),
#   1577603505459789824,
#   '@phillipstemann 2 off, one on.',
#   'https://twitter.com/arvidkahl/status/1577603505459789824',
#   1,
#   1577601026173112320],
#  [datetime.datetime(2022, 10, 5, 2, 30, 22, tzinfo=datetime.timezone.utc),
#   1577486322218008576,
#   'Here\'s a surprising lesson to build a trust-based reputation: don\'t "hack" or manipulate people.',
#   'https://twitter.com/arvidkahl/status/1577486322218008576',
#   99,
#   None],
#  [datetime.datetime(2022, 10, 5, 1, 33, 13, tzinfo=datetime.timezone.utc),
#   1577471942633857025,
#   'Today is a good day to be kind and supportive of each other.',
#   'https://twitter.com/arvidkahl/status/1577471942633857025',
#   155,
#   None],
#  [datetime.datetime(2022, 10, 5, 0, 0, 30, tzinfo=datetime.timezone.utc),
#   1577448609016156166,
#   'Living the life! https://t.co/FhztqP01zU',
#   'https://twitter.com/arvidkahl/status/1577448609016156166',
#   12,
#   None],
#  [datetime.datetime(2022, 10, 4, 23, 26, 18, tzinfo=datetime.timezone.utc),
#   1577440001893318658,
#   'The other 10% are wild experimentation, accepting the possibility of failure, and juggling hot coals for fun.\n\nSounds hard, is hard, but also absolutely worth it. https://t.co/b4vxDzSTkY',
#   'https://twitter.com/arvidkahl/status/1577440001893318658',
#   12,
#   None],
#  [datetime.datetime(2022, 10, 4, 21, 19, 14, tzinfo=datetime.timezone.utc),
#   1577408024008089601,
#   '@jspector Can you be a bit more specific? 🤣',
#   'https://twitter.com/arvidkahl/status/1577408024008089601',
#   5,
#   1577394091976888321],
#  [datetime.datetime(2022, 10, 4, 21, 8, 10, tzinfo=datetime.timezone.utc),
#   1577405238469922825,
#   'I’m still very much in awe of this amazing take on the complexity of our calendar. https://t.co/jlsYcQCFQG',
#   'https://twitter.com/arvidkahl/status/1577405238469922825',
#   15,
#   None],
#  [datetime.datetime(2022, 10, 4, 21, 0, 8, tzinfo=datetime.timezone.utc),
#   1577403218694664192,
#   '@douwevandermeij Best resource for that?',
#   'https://twitter.com/arvidkahl/status/1577403218694664192',
#   0,
#   1577402501015474196],
#  [datetime.datetime(2022, 10, 4, 20, 29, 12, tzinfo=datetime.timezone.utc),
#   1577395433755680768,
#   '@dvassallo Better schmooze up to them early then :P',
#   'https://twitter.com/arvidkahl/status/1577395433755680768',
#   2,
#   1577392952187686913],
#  [datetime.datetime(2022, 10, 4, 20, 15, 15, tzinfo=datetime.timezone.utc),
#   1577391923278581778,
#   '@dvassallo We have a plumber in the family :P',
#   'https://twitter.com/arvidkahl/status/1577391923278581778',
#   2,
#   1577388946119864321],
# ...
#   'https://twitter.com/arvidkahl/status/1566477725354827792',
#   3,
#   1566357047989395456],
#  [datetime.datetime(2022, 9, 4, 13, 11, 33, tzinfo=datetime.timezone.utc),
#   1566413656933519369,
#   '@SamHartmannCom @polak_jasper Revenue is vanity, profit is sanity, cash is king ;)',
#   'https://twitter.com/arvidkahl/status/1566413656933519369',
#   3,
#   1566404979774078976],
#  [datetime.datetime(2022, 9, 4, 1, 46, 48, tzinfo=datetime.timezone.utc),
#   1566241336738603010,
#   '@mmuxdesign The mental health issues that were so obvious after a week were painful to watch. Also how all motivation just evaporated after the world worst was FINALLY done.',
#   'https://twitter.com/arvidkahl/status/1566241336738603010',
#   1,
#   1566240702874488832],
#  [datetime.datetime(2022, 9, 4, 1, 28, 9, tzinfo=datetime.timezone.utc),
#   1566236641584418816,
#   'Inspired. https://t.co/Xhdemy5v00',
#   'https://twitter.com/arvidkahl/status/1566236641584418816',
#   56,
#   None],
#  [datetime.datetime(2022, 9, 4, 1, 4, 15, tzinfo=datetime.timezone.utc),
#   1566230627090894848,
#   'I did write about this recently! \n\nhttps://t.co/MwH3zLuvhm',
#   'https://twitter.com/arvidkahl/status/1566230627090894848',
#   2,
#   1566208424446140416],
#  [datetime.datetime(2022, 9, 4, 1, 3, 56, tzinfo=datetime.timezone.utc),
#   1566230549857185792,
#   '@mmuxdesign But there are inspirational parts: https://t.co/MwH3zLv36U',
#   'https://twitter.com/arvidkahl/status/1566230549857185792',
#   1,
#   1566230292377001984],
#  [datetime.datetime(2022, 9, 4, 1, 2, 55, tzinfo=datetime.timezone.utc),
#   1566230292377001984,
#   '@mmuxdesign Yeah I noticed that too. I remember the days when Nihilum was a thing, and endgame raising has devolved into a media frenzy with hypercompetitive minmaxing that’s just boring to watch. \n\nThey did 500+ progression pulls on a boss this tier. Bizarre. And very little community.',
#   'https://twitter.com/arvidkahl/status/1566230292377001984',
#   2,
#   1566228290976858114],
#  [datetime.datetime(2022, 9, 3, 23, 53, 28, tzinfo=datetime.timezone.utc),
#   1566212815559565312,
#   '@igorbenic Classic is the 20yos from back then now having jobs and families. It’s awesome! It’s nostalgia distilled into a game. Still a massive time-waster.',
#   'https://twitter.com/arvidkahl/status/1566212815559565312',
#   5,
#   1566210377800712195],
#  [datetime.datetime(2022, 9, 3, 23, 36, 1, tzinfo=datetime.timezone.utc),
#   1566208424446140416,
#   'World of Warcraft still captivates my attention. No matter how much gamification and retention psychology they throw at me. \n\nOne thing this game has done for me since 2004 is exposing me to interesting cultural ideas and English words I never knew.\n\nAnyone else play?',
#   'https://twitter.com/arvidkahl/status/1566208424446140416',
#   42,
#   None],
#  [datetime.datetime(2022, 9, 3, 23, 34, 25, tzinfo=datetime.timezone.utc),
#   1566208021642022912,
#   '@dannybster https://t.co/Io9dy2d0bR',
#   'https://twitter.com/arvidkahl/status/1566208021642022912',
#   0,
#   1566188469357002752],
#  [datetime.datetime(2022, 9, 3, 23, 34, 2, tzinfo=datetime.timezone.utc),
#   1566207925357608960,
#   '@LexHuntsman Haha.  It’s an “investment.”',
#   'https://twitter.com/arvidkahl/status/1566207925357608960',
#   1,
#   1566188665528848387],
#  [datetime.datetime(2022, 9, 3, 22, 3, 11, tzinfo=datetime.timezone.utc),
#   1566185062172868610,
#   '@IanMcNay @ArnieEngel19 Yeah that will make all the difference.',
#   'https://twitter.com/arvidkahl/status/1566185062172868610',
#   1,
#   1566178254473527296],
#  [datetime.datetime(2022, 9, 3, 21, 9, 56, tzinfo=datetime.timezone.utc),
#   1566171661237379072,
#   'Here’s the tweet and the conversation that made me write this. https://t.co/oSogGgZy1e',
#   'https://twitter.com/arvidkahl/status/1566171661237379072',
#   5,
#   1566171659903672320],
#  [datetime.datetime(2022, 9, 3, 21, 9, 56, tzinfo=datetime.timezone.utc),
#   1566171659903672320,
#   'It’s with that mindset that I welcome AI tools into my writer toolkit.',
#   'https://twitter.com/arvidkahl/status/1566171659903672320',
#   6,
#   1566171658276184068],
#  [datetime.datetime(2022, 9, 3, 21, 9, 56, tzinfo=datetime.timezone.utc),
#   1566171658276184068,
#   'We all need a place to start from. Tabula rasa is over. The smallest germ of a thought can now be exploded into images, videos, and music. But it will only ever be a variation of what was before.\n\nThe tools we use shape our work, but they’re not limits: they make it possible.',
#   'https://twitter.com/arvidkahl/status/1566171658276184068',
#   5,
#   1566171655256383494],
#  [datetime.datetime(2022, 9, 3, 21, 9, 55, tzinfo=datetime.timezone.utc),
#   1566171655256383494,
#   'I am by no means bashing AI. I think it’s amazing, particularly for creatives. Giving a prompt to a machine and have them create a clear visualization of that scene is every writers dream. But it’s a crutch, not the final result. It’s the start,  it the end.',
#   'https://twitter.com/arvidkahl/status/1566171655256383494',
#   3,
#   1566171653679235073],
#  [datetime.datetime(2022, 9, 3, 21, 9, 54, tzinfo=datetime.timezone.utc),
#   1566171653679235073,
#   'That’s the human touch, the skill of the artisan.\n\nNow, machines will start anticipating these things too. But if they truly unburden us from tedium, we’ll have the time to spend on reflecting, dreaming, and imagining.',
#   'https://twitter.com/arvidkahl/status/1566171653679235073',
#   3,
#   1566171652047650819],
#  [datetime.datetime(2022, 9, 3, 21, 9, 54, tzinfo=datetime.timezone.utc),
#   1566171652047650819,
#   'Because in all the AI-created work, you’ll find that it can’t help but be derivative. That’s how machines learn: by looking at prior art. And while they come up with beautiful recombinations, they can’t “know” what part of their work should be more ingenious.',
#   'https://twitter.com/arvidkahl/status/1566171652047650819',
#   4,
#   1566171650126757889],
#  [datetime.datetime(2022, 9, 3, 21, 9, 54, tzinfo=datetime.timezone.utc),
#   1566171650126757889,
#   'Consider AI-assisted writing. There will be a day when your kindle comes up with a full novel to cater to your tastes. Done within seconds. \n\nBut you’ll still buy books by human authors. For their ingenuity. For the human spark. The unexpected.',
#   'https://twitter.com/arvidkahl/status/1566171650126757889',
#   7,
#   1566171641201278977],
#  [datetime.datetime(2022, 9, 3, 21, 9, 51, tzinfo=datetime.timezone.utc),
#   1566171641201278977,
#   'A lot of people are concerned that AI will replace whole human industries and fields.\n\nThey’re right: things are already changing.\n\nAt the same time, the unceasing interest in artisanal work made by and for humans makes me confident that we’ll never lose these things completely.',
#   'https://twitter.com/arvidkahl/status/1566171641201278977',
#   44,
#   None],
#  [datetime.datetime(2022, 9, 3, 20, 40, 9, tzinfo=datetime.timezone.utc),
#   1566164164015423492,
#   'As a founder, what do you have a hard time saying “no” to?',
#   'https://twitter.com/arvidkahl/status/1566164164015423492',
#   83,
#   None],
#  [datetime.datetime(2022, 9, 3, 20, 24, 21, tzinfo=datetime.timezone.utc),
#   1566160189631373318,
#   '@jf_busse That warrants its own article for sure!',
#   'https://twitter.com/arvidkahl/status/1566160189631373318',
#   1,
#   1566155876095901696],
#  [datetime.datetime(2022, 9, 3, 17, 50, 13, tzinfo=datetime.timezone.utc),
#   1566121399349035008,
#   'I feel blessed to have seen the "before" and the "after."\n\nIt gave me a sense of possibility.',
#   'https://twitter.com/arvidkahl/status/1566121399349035008',
#   10,
#   1566121397142839296],
#  [datetime.datetime(2022, 9, 3, 17, 50, 12, tzinfo=datetime.timezone.utc),
#   1566121397142839296,
#   "I fondly remember the prevalence of Napster and its cousins all around me. The thrill of finding information that wasn't available before, and sharing it with like-minded people.\n\nSeeing Wikipedia growing from a niche project into something else entirely.",
#   'https://twitter.com/arvidkahl/status/1566121397142839296',
#   4,
#   1566121390033539072],
#  [datetime.datetime(2022, 9, 3, 17, 50, 11, tzinfo=datetime.timezone.utc),
#   1566121390033539072,
#   "It imbued a certain sense of techno-positivity in me. It was wild in the beginning, and no one really knew where the technology was heading. But I saw inspiring entrepreneurs take charge. \n\nI also saw how certain kinds of tech just couldn't be stopped.",
#   'https://twitter.com/arvidkahl/status/1566121390033539072',
#   1,
#   1566121381749743621],
#  [datetime.datetime(2022, 9, 3, 17, 50, 9, tzinfo=datetime.timezone.utc),
#   1566121381749743621,
#   'I wonder if growing up during one of the most impactful technological upheavals impacted my path towards entrepreneurship. When I was really little, we still had a rotary phone. \n\nA decade later, computers and mobile phones all over.\n\nI saw what can happen — and how quickly.',
#   'https://twitter.com/arvidkahl/status/1566121381749743621',
#   18,
#   None],
#  [datetime.datetime(2022, 9, 3, 16, 29, 8, tzinfo=datetime.timezone.utc),
#   1566100995750387712,
#   "It's the little things. https://t.co/48F1Owej4p",
#   'https://twitter.com/arvidkahl/status/1566100995750387712',
#   10,
#   None],
#  [datetime.datetime(2022, 9, 3, 14, 31, 46, tzinfo=datetime.timezone.utc),
#   1566071459658797056,
#   '@ashleyrudland Replies show a different picture!',
#   'https://twitter.com/arvidkahl/status/1566071459658797056',
#   0,
#   1566070912436375555],
#  [datetime.datetime(2022, 9, 3, 12, 49, 7, tzinfo=datetime.timezone.utc),
#   1566045626386857985,
#   '@ionalpha_ That’s true. And I haven’t made any value judgment about this for this reason. What I can see that this new technology is incredibly useful and very much potentially damaging.',
#   'https://twitter.com/arvidkahl/status/1566045626386857985',
#   1,
#   1566042075644043265],
#  [datetime.datetime(2022, 9, 3, 12, 29, 14, tzinfo=datetime.timezone.utc),
#   1566040620816338944,
#   '@growth_tracking https://t.co/xQmEQS3AaF',
#   'https://twitter.com/arvidkahl/status/1566040620816338944',
#   1,
#   1566038754837630978],
#  [datetime.datetime(2022, 9, 3, 12, 10, 46, tzinfo=datetime.timezone.utc),
#   1566035975997984774,
#   'Opportunities grow with the tools we use.\n\nI’ve been writing about this in a past newsletter: with Generative AI on the rise, we need to learn how to tell it what to do.\n\nEnter “prompt engineering”, a new skill that already has market places springing up.\n\nhttps://t.co/V7bco1rrIB',
#   'https://twitter.com/arvidkahl/status/1566035975997984774',
#   26,
#   None],
#  [datetime.datetime(2022, 9, 3, 11, 18, 1, tzinfo=datetime.timezone.utc),
#   1566022698752434176,
#   '@OlegLustenko Audience-building, cold DM sales, relationship-building, referral marketing opportunities, flash sales, finding business partners, doing market research.',
#   'https://twitter.com/arvidkahl/status/1566022698752434176',
#   2,
#   1566021650742755329],
#  [datetime.datetime(2022, 9, 3, 1, 24, 4, tzinfo=datetime.timezone.utc),
#   1565873226487578627,
#   '@MeetKevon That’s a very nice way of using Twitter.',
#   'https://twitter.com/arvidkahl/status/1565873226487578627',
#   8,
#   1565854477907021824],
#  [datetime.datetime(2022, 9, 2, 20, 19, 15, tzinfo=datetime.timezone.utc),
#   1565796518317232131,
#   '@rosiesherry This is a VERY good idea.',
#   'https://twitter.com/arvidkahl/status/1565796518317232131',
#   0,
#   1565759481744707584],
#  [datetime.datetime(2022, 9, 2, 19, 51, 18, tzinfo=datetime.timezone.utc),
#   1565789481671835649,
#   '@RohitGulam Thanks for the shoutout!',
#   'https://twitter.com/arvidkahl/status/1565789481671835649',
#   1,
#   1565770681467506688],
#  [datetime.datetime(2022, 9, 2, 19, 50, 10, tzinfo=datetime.timezone.utc),
#   1565789196660494337,
#   'Do you use Twitter with the intention to make money?',
#   'https://twitter.com/arvidkahl/status/1565789196660494337',
#   198,
#   None],
#  [datetime.datetime(2022, 9, 2, 19, 33, 54, tzinfo=datetime.timezone.utc),
#   1565785105469214721,
#   "If you would like to see articles like this in your inbox as soon as they're out, consider signing up for my newsletter. \n\nI'd appreciate it, and 4632 other founders already have my articles delivered to them every Friday.\n\nhttps://t.co/BLLxRvIb5j",
#   'https://twitter.com/arvidkahl/status/1565785105469214721',
#   3,
#   1565785103757885441],
#  [datetime.datetime(2022, 9, 2, 19, 33, 54, tzinfo=datetime.timezone.utc),
#   1565785103757885441,
#   'The podcast is also available on YouTube!\n\nhttps://t.co/TvUvS696D1',
#   'https://twitter.com/arvidkahl/status/1565785103757885441',
#   2,
#   1565785102285737984],
#  [datetime.datetime(2022, 9, 2, 19, 33, 53, tzinfo=datetime.timezone.utc),
#   1565785102285737984,
#   'I talk about this on my podcast: https://t.co/vGg1loVXys',
#   'https://twitter.com/arvidkahl/status/1565785102285737984',
#   2,
#   1565785100108849153],
#  [datetime.datetime(2022, 9, 2, 19, 33, 53, tzinfo=datetime.timezone.utc),
#   1565785100108849153,
#   'A calm SaaS business needs intentional fundamentals.\n\nCore parts of a calm infrastructure:\n\n- choosing a reliable and boring tech stack\n- setting up customer-facing automation\n- creating a business manual\n- abstracting away dependencies\n\nMore on the blog: \nhttps://t.co/3eefQ2tO5V',
#   'https://twitter.com/arvidkahl/status/1565785100108849153',
#   46,
#   None],
#  [datetime.datetime(2022, 9, 2, 14, 17, 29, tzinfo=datetime.timezone.utc),
#   1565705476670636032,
#   '@gjb_builds Thanks, Garry! Most appreciated!',
#   'https://twitter.com/arvidkahl/status/1565705476670636032',
#   1,
#   1565705265412014080],
#  [datetime.datetime(2022, 9, 2, 13, 2, 10, tzinfo=datetime.timezone.utc),
#   1565686521465913344,
#   'If you want to convince people to give your product a shot, show them someone who now lives a better life because they checked it out.',
#   'https://twitter.com/arvidkahl/status/1565686521465913344',
#   89,
#   None],
#  [datetime.datetime(2022, 9, 2, 13, 0, 3, tzinfo=datetime.timezone.utc),
#   1565685987111469056,
#   '★ Just published a new episode of The Bootstrapped Founder: 152: Infrastructure of a Calm SaaS Business. Listen: https://t.co/vGg1loVXys',
#   'https://twitter.com/arvidkahl/status/1565685987111469056',
#   5,
#   None],
#  [datetime.datetime(2022, 9, 2, 12, 41, 27, tzinfo=datetime.timezone.utc),
#   1565681306637406209,
#   "Beta readers are a staple in fiction &amp; non-fiction alike. I had 500 people beta-read The Embedded Entrepreneur. The feedback was substantial. If you need more convincing, here's the great @PatrickRothfuss explaining his writing process with beta readers.\n\nhttps://t.co/ZxIcJF93IH",
#   'https://twitter.com/arvidkahl/status/1565681306637406209',
#   6,
#   None],
#  [datetime.datetime(2022, 9, 2, 2, 24, 8, tzinfo=datetime.timezone.utc),
#   1565525955241803778,
#   'If you like something, start talking about it. It will attract like-minded people: the best audience there is.',
#   'https://twitter.com/arvidkahl/status/1565525955241803778',
#   68,
#   None],
#  [datetime.datetime(2022, 9, 2, 1, 35, 9, tzinfo=datetime.timezone.utc),
#   1565513627402125312,
#   "Niche fame is great. People you care about want to talk to you, and those who don't care about your field of interest aren't interested in you either. People self-select into and out of your field of vision.\n\nIt's spectacular :D https://t.co/RuCbG32WAC",
#   'https://twitter.com/arvidkahl/status/1565513627402125312',
#   21,
#   None],
#  [datetime.datetime(2022, 9, 2, 0, 38, 1, tzinfo=datetime.timezone.utc),
#   1565499250213113858,
#   '@CooperKraussKC @blakecrouch1 https://t.co/A2cRDBCRym',
#   'https://twitter.com/arvidkahl/status/1565499250213113858',
#   1,
#   1565494792724746241],
#  [datetime.datetime(2022, 9, 2, 0, 18, 10, tzinfo=datetime.timezone.utc),
#   1565494254968922112,
#   '@RainbowSteps Hanging out with my pup and a good book in our back yard, looking at trees is my second fav ;)',
#   'https://twitter.com/arvidkahl/status/1565494254968922112',
#   1,
#   1565476460172804097],
#  [datetime.datetime(2022, 9, 2, 0, 17, 41, tzinfo=datetime.timezone.utc),
#   1565494131983618049,
#   '@CooperKraussKC No, what’s that about?',
#   'https://twitter.com/arvidkahl/status/1565494131983618049',
#   1,
#   1565479715179307009],
#  ...]

# %%
tweet_df = pd.DataFrame(tweets, columns=['Date', 'Id', 'Tweet', 'Url', 'Likes', 'ReplyTo'])
tweet_df
# Out:
#                           Date                   Id  \
# 0    2022-10-10 00:48:05+00:00  1579272521752666112
# 1    2022-10-09 23:02:58+00:00  1579246068944220160
# 2    2022-10-09 22:54:10+00:00  1579243854527877120
# 3    2022-10-09 21:54:00+00:00  1579228712548958208
# 4    2022-10-09 20:57:10+00:00  1579214411088424960
# ...                        ...                  ...
# 4995 2022-05-09 18:23:42+00:00  1523730445556326400
# 4996 2022-05-09 15:43:48+00:00  1523690205873860608
# 4997 2022-05-09 15:42:34+00:00  1523689895130148864
# 4998 2022-05-09 15:32:38+00:00  1523687394808983554
# 4999 2022-05-09 15:31:19+00:00  1523687064025600002
#
#                                                   Tweet  \
# 0       @TheAbbyOfComedy I will go about this calmly :)
# 1                   @diogo_gonca Haha, I’ll do my best!
# 2     You don’t need to be original. Most things hav...
# 3     @arsawatt Yeah, for most purposes, they are mo...
# 4     If people are building their own clunky soluti...
# ...                                                 ...
# 4995  As a professional user of Twitter, which of th...
# 4996  @julianvandieken @beeple Yes! Love the advice....
# 4997  @JackEllis @dvassallo I think that SaaS would ...
# 4998  @dvassallo I think we should co-write a book a...
# 4999  @dvassallo …ulterior motives.\n\nFreedom isn't...
#
#                                                     Url  Likes       ReplyTo
# 0     https://twitter.com/arvidkahl/status/157927252...      2  1.579268e+18
# 1     https://twitter.com/arvidkahl/status/157924606...      1  1.579238e+18
# 2     https://twitter.com/arvidkahl/status/157924385...     33           NaN
# 3     https://twitter.com/arvidkahl/status/157922871...      4  1.579223e+18
# 4     https://twitter.com/arvidkahl/status/157921441...     70           NaN
# ...                                                 ...    ...           ...
# 4995  https://twitter.com/arvidkahl/status/152373044...     16           NaN
# 4996  https://twitter.com/arvidkahl/status/152369020...      1  1.523687e+18
# 4997  https://twitter.com/arvidkahl/status/152368989...      3  1.523689e+18
# 4998  https://twitter.com/arvidkahl/status/152368739...      3  1.523687e+18
# 4999  https://twitter.com/arvidkahl/status/152368706...      1  1.523687e+18
#
# [5000 rows x 6 columns]

# %%
tweet_df = tweet_df[tweet_df['ReplyTo'].isnull()]
tweet_df
# Out:
#                           Date                   Id  \
# 2    2022-10-09 22:54:10+00:00  1579243854527877120
# 4    2022-10-09 20:57:10+00:00  1579214411088424960
# 8    2022-10-09 17:59:11+00:00  1579169619004166145
# 14   2022-10-09 15:10:11+00:00  1579127088657108995
# 23   2022-10-09 10:46:29+00:00  1579060725779075072
# ...                        ...                  ...
# 4975 2022-05-10 10:51:05+00:00  1523978930725834752
# 4978 2022-05-10 01:28:06+00:00  1523837249053409280
# 4984 2022-05-09 21:26:33+00:00  1523776463501426688
# 4991 2022-05-09 19:44:52+00:00  1523750871326208003
# 4995 2022-05-09 18:23:42+00:00  1523730445556326400
#
#                                                   Tweet  \
# 2     You don’t need to be original. Most things hav...
# 4     If people are building their own clunky soluti...
# 8     If you want to leave a legacy, help others hel...
# 14    The antidote to hustle culture is building an ...
# 23    Good morning! Have a great Sunday! \n\nInstead...
# ...                                                 ...
# 4975  You know what I love about audience building?\...
# 4978  Skype hasn’t done too well, but it forged a pa...
# 4984  Some of the responses to this dreadful experie...
# 4991  On Twitter, running a giveaway can get you a l...
# 4995  As a professional user of Twitter, which of th...
#
#                                                     Url  Likes  ReplyTo
# 2     https://twitter.com/arvidkahl/status/157924385...     33      NaN
# 4     https://twitter.com/arvidkahl/status/157921441...     70      NaN
# 8     https://twitter.com/arvidkahl/status/157916961...     68      NaN
# 14    https://twitter.com/arvidkahl/status/157912708...    137      NaN
# 23    https://twitter.com/arvidkahl/status/157906072...    227      NaN
# ...                                                 ...    ...      ...
# 4975  https://twitter.com/arvidkahl/status/152397893...     89      NaN
# 4978  https://twitter.com/arvidkahl/status/152383724...     19      NaN
# 4984  https://twitter.com/arvidkahl/status/152377646...     13      NaN
# 4991  https://twitter.com/arvidkahl/status/152375087...     23      NaN
# 4995  https://twitter.com/arvidkahl/status/152373044...     16      NaN
#
# [1308 rows x 6 columns]

# %%
df = tweet_df[['Likes']]
df
# Out:
#       Likes
# 2        33
# 4        70
# 8        68
# 14      137
# 23      227
# ...     ...
# 4975     89
# 4978     19
# 4984     13
# 4991     23
# 4995     16
#
# [1308 rows x 1 columns]

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np

# %%
plt.scatter(df.index, df['Likes'])

# %%
X = np.array(df['Likes']).reshape(-1, 1)
X
# Out:
# array([[33],
#        [70],
#        [68],
#        ...,
#        [13],
#        [23],
#        [16]])

# %%
nbrs = NearestNeighbors(n_neighbors = 10)
nbrs.fit(X)
# Out:
# NearestNeighbors(n_neighbors=10)

# %%
# distances and indexes of k-neaighbors from model outputs
distances, indexes = nbrs.kneighbors(X)
# plot mean of k-distances of each observation
plt.plot(distances.mean(axis =1))

# %%
outlier_index = np.where(distances.mean(axis = 1) > 10)
outlier_index
# Out:
# (array([  48,   90,  143,  482,  489,  491,  515,  568,  600,  682,  706,
#          728,  736,  761,  916, 1111, 1163, 1258]),)

# %%
outlier_values = df.iloc[outlier_index]
outlier_values
# Out:
#       Likes
# 178     451
# 342     324
# 518     952
# 1590    288
# 1609    536
# 1618    992
# 1678    442
# 1855    491
# 1929    336
# 2207    290
# 2232    668
# 2297    481
# 2315    314
# 2390    327
# 2996    353
# 3776    299
# 4126    401
# 4678   4513

# %%
# plot data
plt.scatter(df.index, df['Likes'], color = "b")
# plot outlier values
plt.scatter(outlier_values.index, outlier_values["Likes"], color = "r")

# %%
min(outlier_values['Likes'])
# Out:
# 288

# %%
outlier_values.index
# Out:
# Int64Index([ 178,  342,  518, 1590, 1609, 1618, 1678, 1855, 1929, 2207, 2232,
#             2297, 2315, 2390, 2996, 3776, 4126, 4678],
#            dtype='int64')

# %%
tweet_df
# Out:
#                           Date                   Id  \
# 2    2022-10-09 22:54:10+00:00  1579243854527877120
# 4    2022-10-09 20:57:10+00:00  1579214411088424960
# 8    2022-10-09 17:59:11+00:00  1579169619004166145
# 14   2022-10-09 15:10:11+00:00  1579127088657108995
# 23   2022-10-09 10:46:29+00:00  1579060725779075072
# ...                        ...                  ...
# 4975 2022-05-10 10:51:05+00:00  1523978930725834752
# 4978 2022-05-10 01:28:06+00:00  1523837249053409280
# 4984 2022-05-09 21:26:33+00:00  1523776463501426688
# 4991 2022-05-09 19:44:52+00:00  1523750871326208003
# 4995 2022-05-09 18:23:42+00:00  1523730445556326400
#
#                                                   Tweet  \
# 2     You don’t need to be original. Most things hav...
# 4     If people are building their own clunky soluti...
# 8     If you want to leave a legacy, help others hel...
# 14    The antidote to hustle culture is building an ...
# 23    Good morning! Have a great Sunday! \n\nInstead...
# ...                                                 ...
# 4975  You know what I love about audience building?\...
# 4978  Skype hasn’t done too well, but it forged a pa...
# 4984  Some of the responses to this dreadful experie...
# 4991  On Twitter, running a giveaway can get you a l...
# 4995  As a professional user of Twitter, which of th...
#
#                                                     Url  Likes  ReplyTo
# 2     https://twitter.com/arvidkahl/status/157924385...     33      NaN
# 4     https://twitter.com/arvidkahl/status/157921441...     70      NaN
# 8     https://twitter.com/arvidkahl/status/157916961...     68      NaN
# 14    https://twitter.com/arvidkahl/status/157912708...    137      NaN
# 23    https://twitter.com/arvidkahl/status/157906072...    227      NaN
# ...                                                 ...    ...      ...
# 4975  https://twitter.com/arvidkahl/status/152397893...     89      NaN
# 4978  https://twitter.com/arvidkahl/status/152383724...     19      NaN
# 4984  https://twitter.com/arvidkahl/status/152377646...     13      NaN
# 4991  https://twitter.com/arvidkahl/status/152375087...     23      NaN
# 4995  https://twitter.com/arvidkahl/status/152373044...     16      NaN
#
# [1308 rows x 6 columns]

# %%
Filter_df  = tweet_df.loc[outlier_values.index]
print(Filter_df.sort_values(by=["Likes"]))
# Out:
#                           Date                   Id  \
# 1590 2022-08-07 01:28:08+00:00  1556089777140776966
# 2207 2022-07-15 21:01:08+00:00  1548050050617446403
# 3776 2022-06-08 23:31:07+00:00  1534679445033951238
# 2315 2022-07-09 15:06:07+00:00  1545786382756597760
# 342  2022-09-27 17:05:13+00:00  1574807384836521991
# 2390 2022-07-07 23:27:07+00:00  1545187687430328321
# 1929 2022-07-24 21:55:12+00:00  1551325150066376705
# 2996 2022-06-26 15:10:07+00:00  1541076346067193856
# 4126 2022-05-31 18:11:21+00:00  1531699873032163329
# 1678 2022-08-03 18:06:08+00:00  1554891383168712705
# 178  2022-10-04 00:25:32+00:00  1577092520089358336
# 2297 2022-07-10 01:28:08+00:00  1545942917344366593
# 1855 2022-07-28 12:43:08+00:00  1552635766685179904
# 1609 2022-08-06 15:06:08+00:00  1555933245593853952
# 2232 2022-07-12 23:26:06+00:00  1546999371836923908
# 518  2022-09-18 21:01:06+00:00  1571605256127283200
# 1618 2022-08-06 02:25:07+00:00  1555741731928301568
# 4678 2022-05-16 18:06:06+00:00  1526262732718317578
#
#                                                   Tweet  \
# 1590  Note-taking is one of the most important activ...
# 2207  If people don’t buy your thing, it’s not a “ma...
# 3776  If you have built a small software project, yo...
# 2315  Systems you should never build yourself when b...
# 342   It feels odd to say this, but:\n\nThe best val...
# 2390  If you enjoy frustration, why not try and beco...
# 1929  As a founder in my (very late) 30s, this pictu...
# 2996  Your mental health is what ultimately decides ...
# 4126  Here are 50 bite-sized Twitter growth tips tha...
# 1678  Building a business as a side project while ha...
# 178                     Ah yes. https://t.co/mJo9HXq6GP
# 2297  Making friends on Twitter has changed my life....
# 1855  To be an entrepreneur, you must get comfortabl...
# 1609  Building software is the easy part. The hard p...
# 2232  To be an entrepreneur, you must get comfortabl...
# 518   When you miss an obvious marketing opportunity...
# 1618   Without revenue, it's a project, not a business.
# 4678  The goal is to build a business.\n\nNot to pla...
#
#                                                     Url  Likes  ReplyTo
# 1590  https://twitter.com/arvidkahl/status/155608977...    288      NaN
# 2207  https://twitter.com/arvidkahl/status/154805005...    290      NaN
# 3776  https://twitter.com/arvidkahl/status/153467944...    299      NaN
# 2315  https://twitter.com/arvidkahl/status/154578638...    314      NaN
# 342   https://twitter.com/arvidkahl/status/157480738...    324      NaN
# 2390  https://twitter.com/arvidkahl/status/154518768...    327      NaN
# 1929  https://twitter.com/arvidkahl/status/155132515...    336      NaN
# 2996  https://twitter.com/arvidkahl/status/154107634...    353      NaN
# 4126  https://twitter.com/arvidkahl/status/153169987...    401      NaN
# 1678  https://twitter.com/arvidkahl/status/155489138...    442      NaN
# 178   https://twitter.com/arvidkahl/status/157709252...    451      NaN
# 2297  https://twitter.com/arvidkahl/status/154594291...    481      NaN
# 1855  https://twitter.com/arvidkahl/status/155263576...    491      NaN
# 1609  https://twitter.com/arvidkahl/status/155593324...    536      NaN
# 2232  https://twitter.com/arvidkahl/status/154699937...    668      NaN
# 518   https://twitter.com/arvidkahl/status/157160525...    952      NaN
# 1618  https://twitter.com/arvidkahl/status/155574173...    992      NaN
# 4678  https://twitter.com/arvidkahl/status/152626273...   4513      NaN
